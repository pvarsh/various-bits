# %%
"""
A simple example of an animated plot
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)        # x-array
line, = ax.plot(x, np.sin(x))

def animate(i):
    line.set_ydata(np.sin(x+i/10.0))  # update the data
    return line,

#Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,

ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
    interval=25, blit=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
# --> 789         self._post_draw(framedata, blit)
#     790
#     791     def _init_draw(self):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#     810         # blitting.
#     811         if blit and self._drawn_artists:
# --> 812             self._blit_draw(self._drawn_artists, self._blit_cache)
#     813         else:
#     814             self._fig.canvas.draw_idle()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_draw(self, artists, bg_cache)
#     824             # to automate the process.
#     825             if a.axes not in bg_cache:
# --> 826                 bg_cache[a.axes] = a.figure.canvas.copy_from_bbox(a.axes.bbox)
#     827             a.axes.draw_artist(a)
#     828             updated_ax.append(a.axes)
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'copy_from_bbox'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in _on_timer(self)
#    1269         '''
#    1270         for func, args, kwargs in self.callbacks:
# -> 1271             ret = func(*args, **kwargs)
#    1272             # docstring above explains why we use `if ret == False` here,
#    1273             # instead of `if not ret`.
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     908         # delay and set the callback to one which will then set the interval
#     909         # back.
# --> 910         still_going = Animation._step(self, *args)
#     911         if not still_going and self.repeat:
#     912             self.frame_seq = self.new_frame_seq()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _step(self, *args)
#     767         try:
#     768             framedata = next(self.frame_seq)
# --> 769             self._draw_next_frame(framedata, self._blit)
#     770             return True
#     771         except StopIteration:
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#     785         # Breaks down the drawing of the next frame into steps of pre- and
#     786         # post- draw, as well as the drawing of the frame itself.
# --> 787         self._pre_draw(framedata, blit)
#     788         self._draw_frame(framedata)
#     789         self._post_draw(framedata, blit)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _pre_draw(self, framedata, blit)
#     798         # This default implementation allows blit to clear the frame.
#     799         if blit:
# --> 800             self._blit_clear(self._drawn_artists, self._blit_cache)
#     801
#     802     def _draw_frame(self, framedata):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/animation.py in _blit_clear(self, artists, bg_cache)
#     838         axes = set(a.axes for a in artists)
#     839         for a in axes:
# --> 840             a.figure.canvas.restore_region(bg_cache[a])
#     841
#     842     def _setup_blit(self):
#
# AttributeError: 'FigureCanvasMac' object has no attribute 'restore_region'
